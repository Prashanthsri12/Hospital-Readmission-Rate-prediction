# %%
import sweetviz
import pandas as pd

# %%
data = pd.read_csv('for_tableau.csv')

# %%
data.head(2)
# Out:
#    Unnamed: 0       race  gender  age  admission_type_id  \
# 0           0  Caucasian       1    0                  5
# 1           1  Caucasian       1    0                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        18                    1                 0
# 1                         1                    7                 0
#
#    num_lab_procedures  num_procedures  ...  glipizide-metformin  \
# 0                  41               0  ...                    0
# 1                  59               0  ...                    0
#
#    glimepiride-pioglitazone  metformin-rosiglitazone  metformin-pioglitazone  \
# 0                         0                        0                       0
# 1                         0                        0                       0
#
#    change  diabetesMed  readmitted  number_of_revisit  critical_visits  \
# 0       0            0           0                  1                0
# ...

# %%
report = sweetviz.analyze([data,'Data'],target_feat='readmitted')
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
#
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
#
# Summarizing dataframe:             |▍                    | [  2%]   00:00  -> (00:06 left)
#
# :TARGET::                          |▍                    | [  2%]   00:00  -> (00:06 left)
#
# :TARGET::                          |▉                    | [  4%]   00:00  -> (00:06 left)
#
# :Unnamed: 0:                       |▉                    | [  4%]   00:00  -> (00:06 left)
#
# :Unnamed: 0:                       |█▍                   | [  7%]   00:01  -> (00:15 left)
#
# :race:                             |█▍                   | [  7%]   00:01  -> (00:15 left)
#
# :race:                             |█▊                   | [  9%]   00:01  -> (00:15 left)
#
# :gender:                           |█▊                   | [  9%]   00:01  -> (00:15 left)
#
# ...

# %%
report.show_html('my_report.html')
# Out:
# Report my_report.html was generated! NOTEBOOK/COLAB USERS: no browser will pop up, the report is saved in your notebook/colab files.
